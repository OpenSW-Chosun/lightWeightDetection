# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
# %cd /content/drive/MyDrive/opensource/light
# Out:
# /content/drive/MyDrive/opensource/light

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566162 sha256=74ad263740bf76731eb8ae54d1281fc833056590e3f945992c1e18fff814a697
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
print("face_recognition 모듈이 성공적으로 임포트되었습니다!")
# Out:
# face_recognition 모듈이 성공적으로 임포트되었습니다!

# %%
# !python /content/drive/MyDrive/opensource/light/example.py
# Out:
# 2024-11-04 04:47:31.420524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-04 04:47:31.441109: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-04 04:47:31.447166: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-04 04:47:31.461817: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !mkdir test_videos

# %%
# !python /content/drive/MyDrive/opensource/light/classifiers.py
# Out:
# 2024-11-04 04:49:31.005676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-04 04:49:31.023855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-04 04:49:31.029466: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-04 04:49:31.042775: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install tensorflow

# %%
# !python /content/drive/MyDrive/opensource/light/classifiers.py
# Out:
# 2024-11-04 04:55:22.843336: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-04 04:55:22.861943: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-04 04:55:22.867561: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-04 04:55:22.890167: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# test.py

from classifiers import Meso1, IMGWIDTH  # IMGWIDTH 추가
import numpy as np

# 가상의 데이터 생성
x_train = np.random.rand(10, IMGWIDTH, IMGWIDTH, 3)
y_train = np.random.randint(2, size=(10, 1))  # 이진 분류를 가정

# 모델 초기화
model = Meso1()
# 모델 훈련
model.fit(x_train, y_train)

# 예측
predictions = model.predict(x_train)

#MesoNet은 비디오 내 얼굴 변조를 자동으로 탐지하는 데 특화된 네트워크로,
#딥러닝을 통해 딥페이크와 Face2Face 기술을 효과적으로 감지할 수 있도록 설계되었습니다. 이 연구는 디지털 포렌식과 보안 분야에서 중요한 기여를 하고 있으며,
#비디오 진위 판별에 대한 새로운 가능성을 제시합니다.
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7fdeae77eef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training loss: 0.16597537696361542, accuracy: 0.800000011920929
# ...
